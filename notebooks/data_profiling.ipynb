# %% [markdown]
# # Data Profiling

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
from pathlib import Path
from ydata_profiling import ProfileReport
# Out:
# /tmp/ipykernel_77168/1804429810.py:3: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %% [markdown]
# ## 2. Load the dataset

# %%
csv_path = "../data/raw/store-data-6aa6d7a3f171f140353680.csv"

df = pd.read_csv(csv_path)

# %% [markdown]
# ## 3. Generate the profiling report

# %%
profile = ProfileReport(df)

# %% [markdown]
# ## 4. Export to HTML

# %%
output_path = "../reports/rapport_profiling.html"
profile.to_file(output_path)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   5%|▍         | 1/21 [00:00<00:02,  9.07it/s]
#  10%|▉         | 2/21 [00:00<00:03,  6.27it/s]
#  14%|█▍        | 3/21 [00:00<00:04,  4.16it/s]
# 100%|██████████| 21/21 [00:00<00:00, 24.99it/s][A
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
